# %% [markdown]
# ## d-vectors to argmax to lebels

# %%
import numpy as np
from numpy import load
from fearless.sid.data import prepare_data
import lazy_dataset
import json,pickle
import paderbox as pb

# %%
d_vector_train_seg = load('d_vector_train_seg_fbank.npy')
d_vector_dev_seg = load('d_vector_dev_seg_fbank.npy')

# %%
for i in range(20):
    print(np.argmax(d_vector_train_seg[i]), np.argmax(d_vector_dev_seg[i]))
# Out:
# 116 164
# 133 15
# 111 12
# 164 67
# 127 79
# 12 12
# 66 114
# 111 15
# 57 12
# 15 129
# 56 132
# 12 77
# 131 111
# 88 156
# 56 162
# 56 12
# 114 109
# 15 156
# 44 148
# 69 16

# %%
#train_a[0] = [116,  33,  21, 164, 127,  12,  66, 111,  57,  15] 
#train_a[1] = [56,  12, 131,  88,  56,  56, 114,  15,  93, 144]
#dev_a[0] =[ 66,  15,  12,  67, 131,  12, 114,  15,  12, 138]
#dev_a[1] = [132,  77, 111, 162, 159,  12, 109, 112, 148,  16]

# %% [markdown]
# ## sorted d_vectors

# %%
d_vector_train_seg = load('d_vector_train_seg_fbank.npy')
d_vector_dev_seg = load('d_vector_dev_seg_fbank.npy')

# %%
for i in range(200):
    print(np.argmax(d_vector_train_seg[i]), np.argmax(d_vector_dev_seg[i]))
# Out:
# 0 0
# 43 164
# 66 114
# 0 164
# 0 113
# 58 112
# 125 66
# 0 112
# 49 0
# 0 0
# 0 0
# 0 164
# 0 112
# 0 25
# 0 125
# 0 164
# 0 56
# 85 72
# 0 2
# 44 56
# 164 164
# 0 2
# 49 2
# 0 56
# 58 164
# 117 2
# 0 164
# 0 164
# 164 100
# 0 164
# 0 152
# 0 56
# 164 12
# 164 56
# 0 96
# 0 164
# 0 4
# 0 77
# 0 114
# 0 72
# 56 37
# 58 118
# 0 114
# 164 118
# 0 5
# 0 5
# 0 77
# 2 107
# 0 164
# 0 159
# 0 164
# 0 5
# 0 162
# 0 111
# 58 111
# 0 105
# 0 68
# 164 166
# 0 9
# 0 8
# 19 8
# 0 8
# 0 105
# 0 8
# 0 9
# 0 164
# 0 8
# 56 8
# 0 164
# 0 8
# 45 32
# 66 164
# 0 8
# 0 8
# 56 164
# 1 94
# 1 8
# 88 111
# 88 161
# 54 56
# 164 16
# 1 164
# 1 164
# 1 81
# 1 12
# 1 11
# 1 61
# 1 11
# 1 11
# 1 11
# 1 11
# 2 11
# 2 11
# 2 56
# 2 11
# 2 11
# 2 11
# 2 56
# 44 56
# 2 12
# 2 12
# 2 12
# 2 109
# 45 12
# 2 12
# 2 12
# 2 12
# 2 12
# 2 111
# 2 12
# 2 12
# 2 12
# 2 12
# 2 12
# 2 12
# 2 12
# 2 54
# 2 12
# 164 12
# 16 12
# 2 111
# 2 12
# 2 12
# 2 12
# 2 12
# 2 111
# 2 111
# 164 12
# 2 12
# 2 12
# 2 12
# 2 12
# 2 12
# ...
